# %%
import sys
sys.path.append('../utils')

import libraries
import utils_general
from utils_general import *

# %matplotlib inline

# %%
for i in glob(os.path.join(o_p, '*epoch_045.png')):
    im = cv2.imread(i, cv2.IMREAD_UNCHANGED)
    plot_im(im, alpha=False)

# %%
1.25e-5
# Out:
# 1.25e-05

# %%
0.0000125
# Out:
# 1.25e-05
